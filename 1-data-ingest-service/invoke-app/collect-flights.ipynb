# %% [markdown]
# # I/O
# - Input: Select list of airports IDs
# - Output: Unique list of flight IDs which departed from the selected airports
#
# # Process
# - Airports + date range --> Flights search
#
# # To do
# - Pull flight IDs departing from select
# - Query ultimate list of flight identifiers to send to the cloud function.

# %%
import os
import sys

# if notebook is being run from src directory, change to root directory
if os.getcwd().split(os.sep)[-1] == 'invoke-app':
    try:
        sys.path.remove('')
        sys.path.append('../')
    except: pass
print(os.getcwd())
# Out:
# /workspaces/flight-ml-eta/1-data-ingest-service/invoke-app

# %%
import os
import json
import logging
import requests
from dotenv import load_dotenv
from datetime import datetime as dt
from datetime import timedelta 
import pandas as pd

from google.oauth2 import service_account
from google.cloud import storage
from google.cloud import firestore

from src.auth.FlightAware import FlightAwareAPI
# from src.io.read import *

FA_client = FlightAwareAPI()

identifier = 'AAL1707'

lookback_hours = 7*24
lookfoward_hours = 2*24

# ------ DERIVED TIMESTAMPS ------      
current_time_raw = dt.utcnow()

current_time = current_time_raw.strftime('%Y-%m-%dT%H:%M:%SZ')
query_start = (current_time_raw - timedelta(hours=lookback_hours)).strftime('%Y-%m-%dT%H:%M:%SZ')
query_end = (current_time_raw + timedelta(hours=lookfoward_hours)).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
from urllib.parse import urlparse, parse_qs
import time

def extract_cursor(next_link):
    # Parse the URL from the 'next' link
    parsed_url = urlparse(next_link)
    # Extract the query parameters as a dictionary
    query_params = parse_qs(parsed_url.query)
    # The cursor is under the 'cursor' key
    cursor = query_params.get('cursor', [None])[0]
    return cursor



def paginate_api(api, endpoint, params, data_key, max_pages=10):
    """
    Generic API pagination function.

    :param api: API class instance with a query method
    :param endpoint: API endpoint string
    :param params: Dictionary of parameters to pass to the API
    :param data_key: Key in the response that contains the data to extract
    :param max_pages: Maximum number of pages to fetch
    :return: List of extracted data from all pages
    """
    data = []
    for i in range(max_pages):
        response = api.query(endpoint, **params)
        data.extend(response.get(data_key, []))
        cursor = extract_cursor(response['links']['next']) if 'next' in response.get('links', {}) else None
        print(f'result set {i} finished')
        time.sleep(7)
        if not cursor:
            break
        params['cursor'] = cursor
    return data

def get_airport_departures(api, airport_id, start_datetime, end_datetime, max_pages=100):
    endpoint = f'/airports/{airport_id}/flights/departures'
    params = {'airline': 'AAL', 'end': end_datetime, 'start': start_datetime}

    departures = paginate_api(api, endpoint, params, 'departures', max_pages)
    return pd.json_normalize(departures)

def get_airport_flights(api, airport_id, start_datetime, end_datetime, max_pages=100):
    endpoint = f'/airports/{airport_id}/flights'
    params = {'airline': 'AAL', 'end': end_datetime, 'start': start_datetime}
    
    departures = paginate_api(api, endpoint, params, 'departures', max_pages)
    return pd.json_normalize(departures)

# Usage
flights_df = get_airport_flights(FA_client, 'KDFW', query_start, query_end)
# Out:
# result set 0 finished
# result set 1 finished
# result set 2 finished
# result set 3 finished
# result set 4 finished
# result set 5 finished
# result set 6 finished
# result set 7 finished
# result set 8 finished
# result set 9 finished
# result set 10 finished
# result set 11 finished
# result set 12 finished
# result set 13 finished
# result set 14 finished
# result set 15 finished
# result set 16 finished
# result set 17 finished
# result set 18 finished
# result set 19 finished
# result set 20 finished
# result set 21 finished
# result set 22 finished
# result set 23 finished
# result set 24 finished
# result set 25 finished
# result set 26 finished
# result set 27 finished
# result set 28 finished
# result set 29 finished
# result set 30 finished
# result set 31 finished
# result set 32 finished
# result set 33 finished
# result set 34 finished
# result set 35 finished
# result set 36 finished
# result set 37 finished
# result set 38 finished
# result set 39 finished
# result set 40 finished
# result set 41 finished
# result set 42 finished
# result set 43 finished
# result set 44 finished
# result set 45 finished
# result set 46 finished
# result set 47 finished
# result set 48 finished
# result set 49 finished
# result set 50 finished
# result set 51 finished
# result set 52 finished
# result set 53 finished
# result set 54 finished
# result set 55 finished
# result set 56 finished
# result set 57 finished
# result set 58 finished
# result set 59 finished
# result set 60 finished
# result set 61 finished
# result set 62 finished
# result set 63 finished
# result set 64 finished
# result set 65 finished
# result set 66 finished
# result set 67 finished
# result set 68 finished
# result set 69 finished
# result set 70 finished
# result set 71 finished
# result set 72 finished
# result set 73 finished
# result set 74 finished
# result set 75 finished
# result set 76 finished
# result set 77 finished
# result set 78 finished
# result set 79 finished
# result set 80 finished
# result set 81 finished
# result set 82 finished
# result set 83 finished
# result set 84 finished
# result set 85 finished
# result set 86 finished
# result set 87 finished
# result set 88 finished
# result set 89 finished
# result set 90 finished
# result set 91 finished
# result set 92 finished
# result set 93 finished
# result set 94 finished
# result set 95 finished
# result set 96 finished
# result set 97 finished
# result set 98 finished
# result set 99 finished

# %%
flights_df
# Out:
#         ident ident_icao ident_iata actual_runway_off actual_runway_on  \
# 0      AAL175     AAL175      AA175               18L             None
# 1     AAL2345    AAL2345     AA2345               17C             None
# 2     AAL1662    AAL1662     AA1662               17C             None
# 3     AAL1739    AAL1739     AA1739               17C             None
# 4     AAL1093    AAL1093     AA1093               18L             None
# ...       ...        ...        ...               ...              ...
# 1495  AAL1322    AAL1322     AA1322               18L              34R
# 1496  AAL2457    AAL2457     AA2457               18L              24L
# 1497    AAL70      AAL70       AA70               17C              25R
# 1498  AAL2283    AAL2283     AA2283               17C              22L
# 1499  AAL1086    AAL1086     AA1086               17C               34
#
#                            fa_flight_id operator operator_icao operator_iata  \
# 0        AAL175-1703101160-airline-248p      AAL           AAL            AA
# 1     AAL2345-1703101369-schedule-1102p      AAL           AAL            AA
# 2      AAL1662-1703100844-airline-1367p      AAL           AAL            AA
# 3      AAL1739-1703099884-airline-1865p      AAL           AAL            AA
# 4       AAL1093-1703101160-airline-223p      AAL           AAL            AA
# ...                                 ...      ...           ...           ...
# 1495   AAL1322-1702852989-airline-4892p      AAL           AAL            AA
# 1496   AAL2457-1702852552-schedule-157p      AAL           AAL            AA
# 1497     AAL70-1702851682-airline-3177p      AAL           AAL            AA
# 1498   AAL2283-1702852989-airline-4836p      AAL           AAL            AA
# 1499   AAL1086-1702852989-airline-4995p      AAL           AAL            AA
#
#      flight_number  ...        origin.city origin.airport_info_url  \
# 0              175  ...  Dallas-Fort Worth          /airports/KDFW
# 1             2345  ...  Dallas-Fort Worth          /airports/KDFW
# 2             1662  ...  Dallas-Fort Worth          /airports/KDFW
# 3             1739  ...  Dallas-Fort Worth          /airports/KDFW
# 4             1093  ...  Dallas-Fort Worth          /airports/KDFW
# ...            ...  ...                ...                     ...
# 1495          1322  ...  Dallas-Fort Worth          /airports/KDFW
# 1496          2457  ...  Dallas-Fort Worth          /airports/KDFW
# 1497            70  ...  Dallas-Fort Worth          /airports/KDFW
# 1498          2283  ...  Dallas-Fort Worth          /airports/KDFW
# 1499          1086  ...  Dallas-Fort Worth          /airports/KDFW
#
#      destination.code destination.code_icao destination.code_iata  \
# 0                RJTT                  RJTT                   HND
# 1                KCVG                  KCVG                   CVG
# 2                KPHL                  KPHL                   PHL
# 3                KECP                  KECP                   ECP
# 4                KDEN                  KDEN                   DEN
# ...               ...                   ...                   ...
# 1495             KDEN                  KDEN                   DEN
# 1496             KLAX                  KLAX                   LAX
# 1497             EDDF                  EDDF                   FRA
# 1498             KLIT                  KLIT                   LIT
# 1499             KECP                  KECP                   ECP
#
#       destination.code_lid  destination.timezone  \
# 0                     None            Asia/Tokyo
# 1                      CVG      America/New_York
# 2                      PHL      America/New_York
# 3                      ECP       America/Chicago
# 4                      DEN        America/Denver
# ...                    ...                   ...
# 1495                   DEN        America/Denver
# 1496                   LAX   America/Los_Angeles
# 1497                  None         Europe/Berlin
# 1498                   LIT       America/Chicago
# 1499                   ECP       America/Chicago
#
#                                        destination.name   destination.city  \
# 0                                  Tokyo Int'l (Haneda)                Ota
# 1     Cincinnati/Northern Kentucky International Air...             Hebron
# 2                                     Philadelphia Intl       Philadelphia
# 3                        Northwest Florida Beaches Intl        Panama City
# 4                                           Denver Intl             Denver
# ...                                                 ...                ...
# 1495                                        Denver Intl             Denver
# 1496                                   Los Angeles Intl        Los Angeles
# 1497                                    Frankfurt Int'l  Frankfurt am Main
# 1498                                   Clinton National        Little Rock
# 1499                     Northwest Florida Beaches Intl        Panama City
#
#       destination.airport_info_url
# 0                   /airports/RJTT
# 1                   /airports/KCVG
# 2                   /airports/KPHL
# 3                   /airports/KECP
# 4                   /airports/KDEN
# ...                            ...
# 1495                /airports/KDEN
# 1496                /airports/KLAX
# 1497                /airports/EDDF
# 1498                /airports/KLIT
# 1499                /airports/KECP
#
# [1500 rows x 66 columns]

# %%
flights_df['ident'].value_counts()
# Out:
# ident
# AAL1685    4
# AAL2749    4
# AAL175     3
# AAL2881    3
# AAL1704    3
#           ..
# AAL2917    1
# AAL320     1
# AAL2367    1
# AAL2989    1
# AAL2283    1
# Name: count, Length: 568, dtype: int64

# %%
flights_df['destination.city'].value_counts()
# Out:
# destination.city
# Los Angeles    43
# Phoenix        36
# Miami          35
# Chicago        32
# San Antonio    32
#                ..
# Roatan          1
# Huntsville      1
# Lexington       1
# Lubbock         1
# Little Rock     1
# Name: count, Length: 153, dtype: int64

# %%
import pygwalker as pyg
from IPython.display import HTML
HTML(pyg.walk(flights_df))
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pygwalker as pyg
#       2 from IPython.display import HTML
# ----> 3 HTML(pyg.walk(flights_df))
#
# File /workspaces/flight-ml-eta/1-data-ingest-service/my_venv/lib/python3.10/site-packages/IPython/core/display.py:430, in HTML.__init__(self, data, url, filename, metadata)
#     427     suffix = data[-10:].lower()
#     428     return prefix.startswith("<iframe ") and suffix.endswith("</iframe>")
# --> 430 if warn():
#     431     warnings.warn("Consider using IPython.display.IFrame instead")
#     432 super(HTML, self).__init__(data=data, url=url, filename=filename, metadata=metadata)
#
# File /workspaces/flight-ml-eta/1-data-ingest-service/my_venv/lib/python3.10/site-packages/IPython/core/display.py:426, in HTML.__init__.<locals>.warn()
#     420     return False
#     422 #
#     423 # Avoid calling lower() on the entire data, because it could be a
#     424 # long string and we're only interested in its beginning and end.
#     425 #
# --> 426 prefix = data[:10].lower()
#     427 suffix = data[-10:].lower()
#     428 return prefix.startswith("<iframe ") and suffix.endswith("</iframe>")
#
# TypeError: 'PygWalker' object is not subscriptable
